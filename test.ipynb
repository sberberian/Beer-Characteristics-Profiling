# %%
# Import dependencies
import os
import pandas as pd
import numpy as np
from numpy import nan

# %%
# Load the data
# https://studentaid.gov/data-center/student/portfolio
# Data is from June 2022
file_to_load = os.path.join("Resources", "Portfolio-by-Age-Debt-Size.xls")

# Read the CSV into a DataFrame
age_debt_df = pd.read_excel(file_to_load)
age_debt_df
# Out:
#    Federal Student Loan Portfolio by Borrower Age and Debt Size  \
# 0   Includes outstanding principal and interest ba...
# 1              Data Source: Enterprise Data Warehouse
# 2                            Data as of June 30, 2022
# 3                                                 NaN
# 4
# 5                                           Debt Size
# 6                                        Less than 5K
# 7                                           5K to 10K
# 8                                          10K to 20K
# 9                                          20K to 40K
# 10                                         40K to 60K
# 11                                         60K to 80K
# 12                                        80K to 100K
# 13                                       100K to 200K
# 14                                              200K+
# 15                                                NaN
# 16                                             Notes:
# ...

# %%
# May 2021
# https://www.bls.gov/oes/
file_to_load = os.path.join("Resources", "national_M2021_dl.xlsx")

# Read the CSV into a DataFrame
occupation_df = pd.read_excel(file_to_load)
occupation_df
# Out:
#       AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0       99       U.S.          1         US      0  Cross-industry
# 1       99       U.S.          1         US      0  Cross-industry
# 2       99       U.S.          1         US      0  Cross-industry
# 3       99       U.S.          1         US      0  Cross-industry
# 4       99       U.S.          1         US      0  Cross-industry
# ...    ...        ...        ...        ...    ...             ...
# 1398    99       U.S.          1         US      0  Cross-industry
# 1399    99       U.S.          1         US      0  Cross-industry
# 1400    99       U.S.          1         US      0  Cross-industry
# 1401    99       U.S.          1         US      0  Cross-industry
# 1402    99       U.S.          1         US      0  Cross-industry
#
#              I_GROUP  OWN_CODE OCC_CODE  \
# 0     cross-industry      1235  00-0000
# 1     cross-industry      1235  11-0000
# ...

# %%
for column in occupation_df.columns:
    print(column)
# Out:
# AREA
# AREA_TITLE
# AREA_TYPE
# PRIM_STATE
# NAICS
# NAICS_TITLE
# I_GROUP
# OWN_CODE
# OCC_CODE
# OCC_TITLE
# O_GROUP
# TOT_EMP
# EMP_PRSE
# JOBS_1000
# LOC_QUOTIENT
# PCT_TOTAL
# PCT_RPT
# H_MEAN
# A_MEAN
# MEAN_PRSE
# H_PCT10
# H_PCT25
# H_MEDIAN
# H_PCT75
# H_PCT90
# A_PCT10
# A_PCT25
# A_MEDIAN
# A_PCT75
# A_PCT90
# ANNUAL
# HOURLY

# %%
# Load the data
# https://www.bls.gov/oes/
# May 2021
file_to_load = os.path.join("Resources", "all_data_M_2021.xlsx")

# Read the CSV into a DataFrame
all_data_df = pd.read_excel(file_to_load)
all_data_df
# Out:
#            AREA                                    AREA_TITLE  AREA_TYPE  \
# 0            99                                          U.S.          1
# 1            99                                          U.S.          1
# 2            99                                          U.S.          1
# 3            99                                          U.S.          1
# 4            99                                          U.S.          1
# ...         ...                                           ...        ...
# 406354  5500001   Northwestern Wisconsin nonmetropolitan area          6
# 406355  5500002   Northeastern Wisconsin nonmetropolitan area          6
# 406356  5500003  South Central Wisconsin nonmetropolitan area          6
# 406357  5500004        Western Wisconsin nonmetropolitan area          6
# 406358  6600001                                          Guam          6
#
#        PRIM_STATE   NAICS     NAICS_TITLE         I_GROUP  OWN_CODE OCC_CODE  \
# ...

# %%
# Load the data
file_to_load = os.path.join("Resources", "Portfolio-by-Debt-Size.xls")

# Read the CSV into a DataFrame
debt_df = pd.read_excel(file_to_load)
debt_df

# %%
# Load the data
file_to_load = os.path.join("Resources", "PortfolioSummary.xls")

# Read the CSV into a DataFrame
summary_df = pd.read_excel(file_to_load)
summary_df
